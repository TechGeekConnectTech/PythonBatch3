# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

'''
df=pd.read_csv('D:/PythonBatch3/PythonBatch3/Day15/weather_data.csv')
df['Date']=pd.to_datetime(df['Date'])
df['Month']=df['Date'].dt.month
df['Day']=df['Date'].dt.day
df['Year']=df['Date'].dt.year

weather_pivot=df.groupby(['Month','City'])['Temperature'].mean().unstack()
sns.heatmap(weather_pivot,annot=True,cmap='coolwarm',center=25,linewidths=0.5,fmt=".1f")
plt.title('Average Monthly Temperature by City')
plt.xlabel('City')
plt.ylabel('Month')
'''




df=pd.read_csv('D:/PythonBatch3/PythonBatch3/Day15/stock_market_data.csv')
stock_correlation_data=[]
for company in df['Company'].unique():
    company_data=df[df['Company']==company]
    stock_correlation_data.append(company_data['Close'].values[:min(500,len(company_data))])


stock_corr_df=pd.DataFrame(dict(zip(df['Company'].unique(),stock_correlation_data)))

stock_corr_df=stock_corr_df.corr()
sns.heatmap(stock_corr_df,annot=True,cmap='YlGnBu',linewidths=0.5,center=0,
            square=True,linewidth=0.5,fmt=".2f")
plt.title('Stock Price Correlation Between Companies')
plt.xlabel('Company')
plt.ylabel('Company')
# Out:
# Text(77.92222222222227, 0.5, 'Company')
